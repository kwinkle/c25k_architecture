# %%
import pandas as pd
# for plots
import matplotlib
#%matplotlib qt
# %matplotlib inline
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0) # bigger figure!
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("husl", 5))
sns.set(style="whitegrid",font_scale=3)

# %%
state_log_df = pd.read_csv('state_logger.csv', names=['timestamp','state_id','user_id','condition','self_attitude','expert_attitude','extraversion',\
	'agreeableness','conscientiousness','emotional_stability','openness_experience','activity_level','session_number','programme_state','task_success','session_time',\
	'session_time_remaining','normalised_session_time','programme_time','normalised_programme_time','time_spent_prog_action','time_remain_prog_action',\
	'prog_action_progress','prog_action_duration','speed','relative_speed_average','relative_speed_best','time_since_last_action','normalised_time_since_last_action',\
	'heart_rate','relative_heart_rate','au12','au25','mood','user_run_pb','user_walk_pb','user_run_avg','user_walk_avg'])

state_log_df.head()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       timestamp                              state_id user_id condition  \
# 0  1.560767e+09  bf1cb5d0-74dc-4d2f-ab07-bbb3edf12734      LB   CONTROL
# 1  1.560767e+09  837c39bd-33ce-4e52-b371-a673a190a303      LB   CONTROL
# 2  1.560767e+09  73125210-d8d4-4843-aa90-7cbd3904f333      LB   CONTROL
# 3  1.560767e+09  69908810-1f19-4b7d-8025-3b5fd5918318      LB   CONTROL
# 4  1.560767e+09  f441240d-3819-423c-bad7-12e4c9078d79      LB   CONTROL
#
#    self_attitude  expert_attitude  extraversion  agreeableness  \
# 0            1.0              1.0          0.93           0.93
# 1            1.0              1.0          0.93           0.93
# 2            1.0              1.0          0.93           0.93
# ...

# %%
pd.options.display.max_rows = 999
state_log_df[["user_id","session_number"]].drop_duplicates().sort_values(["user_id", "session_number"])
# Out:
#        user_id  session_number
# 59720       DB               1
# 82875       DB               2
# 95814       DB               3
# 117098      DB               4
# 137492      DB               5
# 166542      DB               6
# 183612      DB               7
# 229045      DB               9
# 299642      DB              10
# 326365      DB              11
# 337871      DB              12
# 388277      DB              13
# 406807      DB              14
# 422910      DB              15
# 447433      DB              16
# 11524       DP               1
# 17165       DP               2
# 49138       DP               3
# 65107       DP               4
# 98214       DP               5
# 103372      DP               6
# 122361      DP               7
# 139721      DP               8
# 161733      DP               9
# 175815      DP              10
# 191186      DP              11
# 198242      DP              12
# 233951      DP              13
# 251608      DP              14
# ...

# %%
state_log_df[(state_log_df['user_id']=="LB") & (state_log_df['session_number']==9) &  (state_log_df['session_time']>=630) &  (state_log_df['session_time']<=722)]
# Out:
#            timestamp                              state_id user_id  \
# 170380  1.562582e+09  74fc562a-759d-4b7f-bae5-8fd2ae1d1d0c      LB
# 170381  1.562582e+09  8f5cb2c2-6906-49ad-b9cc-ea560933b499      LB
# 170382  1.562582e+09  3363593d-1063-41a2-82a9-bacd9e7a437b      LB
# 170383  1.562582e+09  c63b227f-9596-4e2f-b369-af6e174aa018      LB
# 170384  1.562582e+09  16699fc1-f568-49b2-bab3-46cdb7de5a36      LB
# 170385  1.562582e+09  90e042d0-3759-48da-ae55-0856a097f21e      LB
# 170386  1.562582e+09  a738b356-f919-4d4e-8d67-7617b85e654c      LB
# 170387  1.562582e+09  9811186b-9521-4c5c-b0fb-add71fcb32c5      LB
# 170388  1.562582e+09  c52b5957-cdbb-4611-a43d-45a8901e5634      LB
# 170389  1.562582e+09  f0496609-29de-4bd2-bb0b-3591d1f1d07b      LB
# 170390  1.562582e+09  ba52a79b-c501-474c-909d-5520230d4a8b      LB
# 170391  1.562582e+09  fb9e76e7-112c-4b0b-a522-1040706c54a3      LB
# 170392  1.562582e+09  d6d16207-9920-4536-bb5d-0bc44042d9a1      LB
# ...

# %%
state_log_df[state_log_df['speed']>8][["user_id","session_number"]].drop_duplicates().sort_values(["user_id", "session_number"])
# Out:
#        user_id  session_number
# 59755       DB               1
# 83015       DB               2
# 95825       DB               3
# 117109      DB               4
# 146889      DB               5
# 166623      DB               6
# 140107      DP               8
# 176421      DP              10
# 191190      DP              11
# 198277      DP              12
# 2417        FB               1
# 9032        FB               2
# 41236       FB               3
# 67928       FB               4
# 85572       FB               5
# 6550        GB               1
# 38959       GB               2
# 57227       GB               3
# 80270       GB               4
# 112679      GB               6
# 19680       JF               1
# 43933       JF               2
# 54734       JF               3
# 70595       JF               4
# 108632      JF               5
# 132908      JF               6
# 144731      JF               7
# 172879      JF               8
# 6211        JW               1
# ...

# %%
#state_log_df.groupby(["user_id"])["speed"].hist(bins=30)
state_log_df[state_log_df["user_id"] == "LB"]["prog_action_progress"].hist(bins=100)
#for title, group in state_log_df.groupby('user_id'):
#    print(title)
#    group["speed"].hist(bins=30)

# %%
state_log_df.loc(state_log_df['speed']==0)["speed"] = -1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-5073fb5722e7> in <module>()
# ----> 1 state_log_df.loc(state_log_df['speed']==0)["speed"] = -1
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     101
#     102         if axis is not None:
# --> 103             axis = self.obj._get_axis_number(axis)
#     104         new_self.axis = axis
#     105         return new_self
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     345
#     346     def _get_axis_number(self, axis):
# --> 347         axis = self._AXIS_ALIASES.get(axis, axis)
#     348         if is_integer(axis):
#     349             if axis in self._AXIS_NAMES:
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __hash__(self)
#    1043     def __hash__(self):
# ...

# %%
#pd.set_option('display.max_cols', 200000000)

state_log_df.loc[state_log_df.loc[:,"speed"]==0] = float("NaN")

# %%
state_log_df.loc[state_log_df.loc[:,"speed"].isna()].shape
# Out:
# (18578, 38)

# %%
state_log_df.loc[state_log_df.loc[:,"speed"]==0][:, "speed"] = float("NaN")
state_log_df.loc[(state_log_df.loc[:,"speed"]>7.9) & (state_log_df.loc[:,"user_id"] != "GB") & (state_log_df.loc[:,"user_id"] != "DB")] = float("NaN")
state_log_df.loc[(state_log_df["user_id"] == "DB") & (state_log_df["speed"] <= 7.71) & (state_log_df["speed"] >= 7.69)]["speed"]

# %%
state_log_df.loc[state_log_df.loc[:,"speed"].isna()].shape
# Out:
# (21475, 38)

# %%
import numpy as np
count, division = np.histogram(state_log_df[state_log_df["user_id"] == "DB"]["speed"], bins=100)

# %%
np.argmax(count)
# Out:
# 75

# %%
state_log_df.loc[state_log_df.loc[:,"speed"]==0].T.loc["speed"] = float("NaN")

state_log_df[state_log_df.loc[:,"speed"].isna()]
# Out:
#            timestamp                              state_id user_id condition  \
# 200929  1.562860e+09  9a39d391-3441-48b5-9ff2-c02ac74f6a65      MR   CONTROL
# 200930  1.562860e+09  4de65464-1b67-4d5f-ab0f-1dfd14f1b534      MR   CONTROL
# 200931  1.562860e+09  5bebe276-f734-486a-aeea-24da2f714a01      MR   CONTROL
# 200932  1.562860e+09  bd289cd6-9246-4cf4-bcc3-fa8c7a7e4df3      MR   CONTROL
# 200933  1.562860e+09  be412a8a-8bf6-40dd-8c8c-c0d5836e46b0      MR   CONTROL
# 200934  1.562860e+09  9a34fdf3-1a0e-4843-bd4d-f2b869db2ed4      MR   CONTROL
# 201102  1.562861e+09  a6724142-21c1-400c-ad06-1ff24d7e730d      MR   CONTROL
# 201103  1.562861e+09  0a94ac01-b15b-40aa-ad21-47c87cac7952      MR   CONTROL
# 201104  1.562861e+09  7997c6c5-01de-4824-a229-7a57f096e8a0      MR   CONTROL
# 201105  1.562861e+09  79c1f39e-2873-4075-8413-11bee39cc6c6      MR   CONTROL
# 201106  1.562861e+09  9d47a13f-f92c-4fdc-a913-9f0e044a2def      MR   CONTROL
# ...

# %%
state_log_df[state_log_df.loc[:,"speed"].isna()]
# Out:
#            timestamp                              state_id user_id condition  \
# 200929  1.562860e+09  9a39d391-3441-48b5-9ff2-c02ac74f6a65      MR   CONTROL
# 200930  1.562860e+09  4de65464-1b67-4d5f-ab0f-1dfd14f1b534      MR   CONTROL
# 200931  1.562860e+09  5bebe276-f734-486a-aeea-24da2f714a01      MR   CONTROL
# 200932  1.562860e+09  bd289cd6-9246-4cf4-bcc3-fa8c7a7e4df3      MR   CONTROL
# 200933  1.562860e+09  be412a8a-8bf6-40dd-8c8c-c0d5836e46b0      MR   CONTROL
# 200934  1.562860e+09  9a34fdf3-1a0e-4843-bd4d-f2b869db2ed4      MR   CONTROL
# 201102  1.562861e+09  a6724142-21c1-400c-ad06-1ff24d7e730d      MR   CONTROL
# 201103  1.562861e+09  0a94ac01-b15b-40aa-ad21-47c87cac7952      MR   CONTROL
# 201104  1.562861e+09  7997c6c5-01de-4824-a229-7a57f096e8a0      MR   CONTROL
# 201105  1.562861e+09  79c1f39e-2873-4075-8413-11bee39cc6c6      MR   CONTROL
# 201106  1.562861e+09  9d47a13f-f92c-4fdc-a913-9f0e044a2def      MR   CONTROL
# ...

# %%
state_log_df.loc[state_log_df.loc[:,"speed"]==0] = -1
state_log_df.loc[state_log_df.loc[:,"speed"]==-1]
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# ...

# %%
fixed_state_log_df = pd.read_csv('state_logger.csv', names=['timestamp','state_id','user_id','condition','self_attitude','expert_attitude','extraversion',\
	'agreeableness','conscientiousness','emotional_stability','openness_experience','activity_level','session_number','programme_state','task_success','session_time',\
	'session_time_remaining','normalised_session_time','programme_time','normalised_programme_time','time_spent_prog_action','time_remain_prog_action',\
	'prog_action_progress','prog_action_duration','speed','relative_speed_average','relative_speed_best','time_since_last_action','normalised_time_since_last_action',\
	'heart_rate','relative_heart_rate','au12','au25','mood','user_run_pb','user_walk_pb','user_run_avg','user_walk_avg'])

state_log_df.head()
# Out:
# /home/katie/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e158db5e9975> in <module>()
# ...

# %%
fixed_state_log_df[fixed_state_log_df["user_id"] == "PT"]["speed"].hist(bins=100)

# %%
fixed_state_log_df[(fixed_state_log_df["user_id"] == "GB") & (fixed_state_log_df["session_number"] == 5)] #& (fixed_state_log_df["session_time"] > 359) & (fixed_state_log_df["session_time"] < 362)]
# Out:
# Empty DataFrame
# Columns: [timestamp, state_id, user_id, condition, self_attitude, expert_attitude, extraversion, agreeableness, conscientiousness, emotional_stability, openness_experience, activity_level, session_number, programme_state, task_success, session_time, session_time_remaining, normalised_session_time, programme_time, normalised_programme_time, time_spent_prog_action, time_remain_prog_action, prog_action_progress, prog_action_duration, speed, relative_speed_average, relative_speed_best, time_since_last_action, normalised_time_since_last_action, heart_rate, relative_heart_rate, au12, au25, mood, user_run_pb, user_walk_pb, user_run_avg, user_walk_avg]
# Index: []
